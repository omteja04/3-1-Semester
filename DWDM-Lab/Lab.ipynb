# %% [markdown]
# **Write a program to compute/display dissimilarity matrix (for your own dataset containing at least four instances with two attributes) using Python**

# %%
# Import the necessary libraries
import numpy as np
from scipy.spatial import distance_matrix

# Define two matrices (arrays) of points in 2D space
x = np.array([[1, 2], [2, 1], [2, 2]])  # Points in matrix x
y = np.array([[5, 0], [1, 2], [2, 0]])  # Points in matrix y

# Print the matrices for reference
print("matrix x: \n", x)
print("matrix y: \n", y)

# Calculate the Euclidean distance matrix between points in x and y
# `p=2` specifies Euclidean distance; for Manhattan distance, `p=1` would be used
dist_mat = distance_matrix(x, y, p=2)

# Print the resulting distance matrix
print("dist_matrix x: \n", dist_mat)
# Out:
# matrix x:
#  [[1 2]
#  [2 1]
#  [2 2]]
# matrix y:
#  [[5 0]
#  [1 2]
#  [2 0]]
# dist_matrix x:
#  [[4.47213595 0.         2.23606798]
#  [3.16227766 1.41421356 1.        ]
#  [3.60555128 1.         2.        ]]

# %% [markdown]
# **Write a program of cluster analysis using simple k-means algorithm Python programming language.**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

# Set theme
sns.set_theme()

# Generate synthetic data
x, y_true = make_blobs(n_samples=400, centers=4, cluster_std=0.60, random_state=0)

# Initial scatter plot
plt.scatter(x[:, 0], x[:, 1], s=20)
plt.show()

# KMeans clustering
kmeans = KMeans(n_clusters=4)
kmeans.fit(x)
y_kmeans = kmeans.predict(x)

# Plot with clusters and centroids
plt.scatter(x[:, 0], x[:, 1], c=y_kmeans, s=20, cmap="viridis")
centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c="blue", s=100, alpha=0.9)
plt.show()

# %% [markdown]
# **Write a program to calculate chi-square value using Python. Report your observation.**

# %%
from scipy.stats import chi2_contingency

# Example contingency table (2x2 format)
# Observed data: [[A, B], [C, D]]
observed_data = [
    [207, 282, 241],  # Group 1 counts (observed)
    [234, 242, 232]   # Group 2 counts (observed)
]

# Calculate the chi-square test statistic, p-value, degrees of freedom, and expected frequencies
chi2, p, dof, expected = chi2_contingency(observed_data)

print("Observed Data:\n", observed_data)
print("\nExpected Data (under null hypothesis):\n", expected)
print("\nChi-Square Statistic:", chi2)
print("Degrees of Freedom:", dof)
print("p-value:", p)

# Interpretation based on p-value
alpha = 0.05  # significance level
if p < alpha:
    print("\nObservation: Dependent (reject null hypothesis).")
else:
    print("\nObservation: Independent (null hypothesis holds true).")
# Out:
# Observed Data:
#  [[207, 282, 241], [234, 242, 232]]
#
# Expected Data (under null hypothesis):
#  [[223.87343533 266.00834492 240.11821975]
#  [217.12656467 257.99165508 232.88178025]]
#
# Chi-Square Statistic: 4.542228269825232
# Degrees of Freedom: 2
# p-value: 0.10319714047309392
#
# Observation: Independent (null hypothesis holds true).
